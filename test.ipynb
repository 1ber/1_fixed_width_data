# %%
from FixedWidthFile import *

series=read_copybook_file('series2.cob')
# To test with a bigger file just unzip big_data.txt.zip and change the name
# bellow from data.txt to big_data.txt
dataframe=read_fixed_width_file(series, 'data.txt', {'record_type':1})
dataframe.date=pd.to_datetime(dataframe.date, format='%Y%m%d')
dataframe.head()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# {'record_type': 1}
# record_type 1
#    record_type       date stock_type ticket_code market_type  short_name  \
# 1            1 2023-01-02        2.0       NEOE3          10  NEOENERGIA
# 2            1 2023-01-02        2.0       NEXP3          10       NEXPE
# 3            1 2023-01-02        2.0       NGRD3          10     NEOGRID
# 4            1 2023-01-02        2.0       NINJ3          10   GETNINJAS
# 5            1 2023-01-02        2.0       NORD3          10  NORDON MET
#
#   ticket_class days_vest currency  opening_price  ...  deals  share_numbers  \
# 1   ON      NM       nan       R$          15.40  ...   1916         325000
# 2   ON      NM       nan       R$           0.31  ...    255         197700
# 3   ON      NM       nan       R$           1.48  ...   1011         589900
# 4   ON      NM       nan       R$           2.70  ...    421          76000
# ...
